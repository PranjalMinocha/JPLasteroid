# %% [markdown]
# <a href="https://colab.research.google.com/github/PranjalMinocha/JPLasteroid/blob/main/vrinda_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Asteroid_Updated.csv"

df = pd.read_csv(path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,10,15,16,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#       name         a         e          i          om           w         q  \
# 0    Ceres  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684
# 1   Pallas  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865
# 2     Juno  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332
# 3    Vesta  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909
# 4  Astraea  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324
#
#          ad     per_y  data_arc  ...     UB  IR  spec_B spec_T     G     moid  \
# 0  2.979647  4.608202    8822.0  ...  0.426 NaN       C      G  0.12  1.59478
# 1  3.411067  4.616444   72318.0  ...  0.284 NaN       B      B  0.11  1.23324
# 2  3.354967  4.360814   72684.0  ...  0.433 NaN      Sk      S  0.32  1.03454
# 3  2.570926  3.628837   24288.0  ...  0.492 NaN       V      V  0.32  1.13948
# 4  3.066174  4.130323   63507.0  ...  0.411 NaN       S      S   NaN  1.09589
#
#   class         n          per          ma
# 0   MBA  0.213885  1683.145708   77.372096
# 1   MBA  0.213503  1686.155999   59.699133
# 2   MBA  0.226019  1592.787285   34.925016
# 3   MBA  0.271609  1325.432765   95.861936
# 4   MBA  0.238632  1508.600458  282.366289
#
# [5 rows x 31 columns]

# %%
list(df.columns)
# Out:
# ['name',
#  'a',
#  'e',
#  'i',
#  'om',
#  'w',
#  'q',
#  'ad',
#  'per_y',
#  'data_arc',
#  'condition_code',
#  'n_obs_used',
#  'H',
#  'neo',
#  'pha',
#  'diameter',
#  'extent',
#  'albedo',
#  'rot_per',
#  'GM',
#  'BV',
#  'UB',
#  'IR',
#  'spec_B',
#  'spec_T',
#  'G',
#  'moid',
#  'class',
#  'n',
#  'per',
#  'ma']

# %%
df.shape
# Out:
# (839714, 31)

# %%
df.dtypes
# Out:
# name               object
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# neo                object
# pha                object
# diameter           object
# extent             object
# albedo            float64
# rot_per           float64
# GM                float64
# BV                float64
# UB                float64
# IR                float64
# spec_B             object
# spec_T             object
# G                 float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
df.describe()
# Out:
#                    a              e              i             om  \
# count  839712.000000  839714.000000  839714.000000  839714.000000
# mean        2.757514       0.155636       8.949826     168.499466
# std       114.384959       0.093897       6.666087     103.096307
# min   -104279.220927       0.000000       0.007546       0.000388
# 25%         2.385258       0.091454       4.069077      80.211400
# 50%         2.644219       0.143655       7.257101     160.294860
# 75%         2.996048       0.199400      12.255653     252.201519
# max      3043.149073       1.201134     175.188725     359.999800
#
#                    w              q             ad          per_y  \
# count  839714.000000  839714.000000  839708.000000  839713.000000
# mean      181.075796       2.404728       3.385710       6.859734
# std       104.023854       2.233172      12.748733     252.264249
# min         0.001666       0.070511       0.773684       0.000000
# 25%        91.041603       1.971941       2.775350       3.683928
# 50%       181.669478       2.225510       3.037761       4.299859
# 75%       271.521717       2.578162       3.357967       5.185985
# max       359.999833      80.424175    6081.841956  167877.712688
#
#             data_arc     n_obs_used  ...       rot_per            GM  \
# count  824240.000000  839714.000000  ...  18796.000000  1.400000e+01
# mean     5688.422331     259.191837  ...     21.136772  7.821928e+00
# std      4208.177231     371.759667  ...     73.131751  1.678880e+01
# min         0.000000       2.000000  ...      0.004389  2.100000e-09
# 25%      3608.000000      50.000000  ...      4.210000  1.022225e-03
# 50%      5806.000000     118.000000  ...      6.653000  6.192500e-01
# 75%      7270.000000     296.000000  ...     12.624250  6.500000e+00
# max     72684.000000    9325.000000  ...   3240.000000  6.262840e+01
#
#                 BV          UB    IR           G          moid             n  \
# count  1021.000000  979.000000  1.00  119.000000  8.232720e+05  8.397120e+05
# mean      0.769212    0.364396 -0.33    0.178739  1.423371e+00  2.374145e-01
# std       0.088625    0.095780   NaN    0.134603  2.250450e+00  8.095014e-02
# min       0.580000    0.120000 -0.33   -0.250000  3.437640e-07  2.926897e-08
# 25%       0.700000    0.289000 -0.33    0.100000  9.784998e-01  1.900553e-01
# 50%       0.743000    0.360000 -0.33    0.190000  1.237810e+00  2.292228e-01
# 75%       0.850000    0.439000 -0.33    0.250000  1.590560e+00  2.675475e-01
# max       1.077000    0.655000 -0.33    0.600000  7.950130e+01  2.381994e+00
#
#                 per             ma
# count  8.397080e+05  839706.000000
# mean   2.505533e+03     180.659892
# std    9.213979e+04     106.562235
# min    1.511339e+02     -67.136826
# 25%    1.345555e+03      86.642618
# 50%    1.570524e+03     181.517775
# 75%    1.894184e+03     274.301731
# max    6.131733e+07     491.618014
#
# [8 rows x 22 columns]

# %%
df.isna()
# Out:
#          name      a      e      i     om      w      q     ad  per_y  \
# 0       False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...
# 839709   True  False  False  False  False  False  False  False  False
# 839710   True  False  False  False  False  False  False  False  False
# 839711   True  False  False  False  False  False  False  False  False
# 839712   True  False  False  False  False  False  False  False  False
# 839713   True  False  False  False  False  False  False  False  False
#
#         data_arc  ...     UB    IR  spec_B  spec_T      G   moid  class  \
# 0          False  ...  False  True   False   False  False  False  False
# 1          False  ...  False  True   False   False  False  False  False
# 2          False  ...  False  True   False   False  False  False  False
# 3          False  ...  False  True   False   False  False  False  False
# 4          False  ...  False  True   False   False   True  False  False
# ...          ...  ...    ...   ...     ...     ...    ...    ...    ...
# 839709     False  ...   True  True    True    True   True  False  False
# 839710     False  ...   True  True    True    True   True  False  False
# 839711     False  ...   True  True    True    True   True  False  False
# 839712     False  ...   True  True    True    True   True  False  False
# 839713     False  ...   True  True    True    True   True  False  False
#
#             n    per     ma
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 839709  False  False  False
# 839710  False  False  False
# 839711  False  False  False
# 839712  False  False  False
# 839713  False  False  False
#
# [839714 rows x 31 columns]

# %%
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839714 entries, 0 to 839713
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            21967 non-null   object
#  1   a               839712 non-null  float64
#  2   e               839714 non-null  float64
#  3   i               839714 non-null  float64
#  4   om              839714 non-null  float64
#  5   w               839714 non-null  float64
#  6   q               839714 non-null  float64
#  7   ad              839708 non-null  float64
#  8   per_y           839713 non-null  float64
#  9   data_arc        824240 non-null  float64
#  10  condition_code  838847 non-null  object
#  11  n_obs_used      839714 non-null  int64
#  12  H               837025 non-null  float64
#  13  neo             839708 non-null  object
#  14  pha             823272 non-null  object
#  15  diameter        137636 non-null  object
#  16  extent          18 non-null      object
#  17  albedo          136409 non-null  float64
#  18  rot_per         18796 non-null   float64
#  19  GM              14 non-null      float64
#  20  BV              1021 non-null    float64
#  21  UB              979 non-null     float64
#  22  IR              1 non-null       float64
#  23  spec_B          1666 non-null    object
#  24  spec_T          980 non-null     object
#  25  G               119 non-null     float64
#  26  moid            823272 non-null  float64
#  27  class           839714 non-null  object
#  28  n               839712 non-null  float64
#  29  per             839708 non-null  float64
#  30  ma              839706 non-null  float64
# dtypes: float64(21), int64(1), object(9)
# memory usage: 198.6+ MB

# %%
df['diameter'].isnull().sum()
# Out:
# 702078

# %%
df[df['diameter'].isnull()].head()
# Out:
#           name         a         e          i          om           w  \
# 681      Hagar  2.654040  0.171983  11.505647  190.799959  104.993824
# 698       Hela  2.610998  0.410284  15.299180  242.551766   91.399514
# 718     Albert  2.638780  0.546301  11.564845  183.887287  156.163668
# 729  Athanasia  2.243362  0.177505   4.234895   95.073806  123.549777
# 842   Nicolaia  2.279598  0.209766   7.997715    4.071354  316.957209
#
#             q        ad     per_y  data_arc  ...     UB  IR  spec_B spec_T  \
# 681  2.197591  3.110489  4.323837   40313.0  ...    NaN NaN     NaN    NaN
# 698  1.539746  3.682249  4.219081   42540.0  ...  0.386 NaN      Sq      S
# 718  1.197212  4.080348  4.286601   39478.0  ...    NaN NaN       S    NaN
# 729  1.845154  2.641570  3.360139   39112.0  ...    NaN NaN     NaN    NaN
# 842  1.801415  2.757780  3.441878   37651.0  ...    NaN NaN     NaN    NaN
#
#       G      moid class         n          per          ma
# 681 NaN  1.215450   MBA  0.227952  1579.281370  134.457728
# 698 NaN  0.624487   MCA  0.233612  1541.019467  237.586385
# 718 NaN  0.203359   AMO  0.229932  1565.680891   48.317252
# 729 NaN  0.841461   MBA  0.293329  1227.290668  295.120065
# 842 NaN  0.798230   MBA  0.286363  1257.146084  317.982712
#
# [5 rows x 31 columns]

# %%
df=df[df['diameter'].notnull()]

# %%
print(df.shape)
# Out:
# (137636, 31)

# %%
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.describe()
# Out:
#                    a              e              i             om  \
# count  137636.000000  137636.000000  137636.000000  137636.000000
# mean        2.814613       0.145485      10.349182     169.827629
# std         1.522740       0.077573       6.835111     102.713052
# min         0.626226       0.000489       0.021855       0.000738
# 25%         2.536714       0.089623       5.120506      82.334880
# 50%         2.750859       0.138543       9.389963     160.438430
# 75%         3.092537       0.191141      13.738588     256.268387
# max       389.145964       0.984348     170.323647     359.990858
#
#                    w              q             ad          per_y  \
# count  137636.000000  137636.000000  137636.000000  137636.000000
# mean      181.904551       2.402609       3.226618       4.884248
# std       103.556464       0.516169       2.896374      25.532565
# min         0.004466       0.081882       0.999956       0.495569
# 25%        91.947943       2.068948       2.864438       4.040317
# 50%       183.669900       2.363897       3.167516       4.562581
# 75%       271.762261       2.685811       3.468608       5.438518
# max       359.995174      40.465671     772.201080    7676.742943
#
#             data_arc     n_obs_used  ...       rot_per            GM  \
# count  137498.000000  137636.000000  ...  11188.000000  1.400000e+01
# mean     8969.818601     675.027740  ...     23.566011  7.821928e+00
# std      6165.176190     595.935104  ...     74.829904  1.678880e+01
# min         1.000000       5.000000  ...      0.029952  2.100000e-09
# 25%      6291.000000     215.000000  ...      4.670000  1.022225e-03
# 50%      7572.000000     496.000000  ...      7.560000  6.192500e-01
# 75%      9731.000000     984.000000  ...     14.579500  6.500000e+00
# max     72684.000000    9325.000000  ...   1880.000000  6.262840e+01
#
#                 BV          UB    IR           G           moid  \
# count  1005.000000  965.000000  1.00  119.000000  137636.000000
# mean      0.768844    0.364108 -0.33    0.178739       1.420145
# std       0.088327    0.095707   NaN    0.134603       0.512241
# min       0.580000    0.120000 -0.33   -0.250000       0.000166
# 25%       0.700000    0.289000 -0.33    0.100000       1.082523
# 50%       0.743000    0.360000 -0.33    0.190000       1.384935
# 75%       0.850000    0.439000 -0.33    0.250000       1.699385
# max       1.077000    0.655000 -0.33    0.600000      39.507000
#
#                    n           per             ma
# count  137636.000000  1.376360e+05  137636.000000
# mean        0.219640  1.783972e+03     183.116785
# std         0.056980  9.325769e+03     103.411497
# min         0.000128  1.810067e+02       0.000517
# 25%         0.181231  1.475726e+03      94.301261
# 50%         0.216024  1.666483e+03     186.826667
# 75%         0.243948  1.986419e+03     271.468299
# max         1.988877  2.803930e+06     359.999979
#
# [8 rows x 22 columns]

# %%
df.isna()
# Out:
#          name      a      e      i     om      w      q     ad  per_y  \
# 0       False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...
# 797860   True  False  False  False  False  False  False  False  False
# 798077   True  False  False  False  False  False  False  False  False
# 798189   True  False  False  False  False  False  False  False  False
# 799752   True  False  False  False  False  False  False  False  False
# 810375   True  False  False  False  False  False  False  False  False
#
#         data_arc  ...     UB    IR  spec_B  spec_T      G   moid  class  \
# 0          False  ...  False  True   False   False  False  False  False
# 1          False  ...  False  True   False   False  False  False  False
# 2          False  ...  False  True   False   False  False  False  False
# 3          False  ...  False  True   False   False  False  False  False
# 4          False  ...  False  True   False   False   True  False  False
# ...          ...  ...    ...   ...     ...     ...    ...    ...    ...
# 797860     False  ...   True  True    True    True   True  False  False
# 798077     False  ...   True  True    True    True   True  False  False
# 798189     False  ...   True  True    True    True   True  False  False
# 799752     False  ...   True  True    True    True   True  False  False
# 810375     False  ...   True  True    True    True   True  False  False
#
#             n    per     ma
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 797860  False  False  False
# 798077  False  False  False
# 798189  False  False  False
# 799752  False  False  False
# 810375  False  False  False
#
# [137636 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  extent          16 non-null      object
#  17  albedo          136406 non-null  float64
#  18  rot_per         11188 non-null   float64
#  19  GM              14 non-null      float64
#  20  BV              1005 non-null    float64
#  21  UB              965 non-null     float64
#  22  IR              1 non-null       float64
#  23  spec_B          1370 non-null    object
#  24  spec_T          965 non-null     object
#  25  G               119 non-null     float64
#  26  moid            137636 non-null  float64
#  27  class           137636 non-null  object
#  28  n               137636 non-null  float64
#  29  per             137636 non-null  float64
#  30  ma              137636 non-null  float64
# dtypes: float64(21), int64(1), object(9)
# memory usage: 33.6+ MB

# %%
df['GM'].isnull().sum()
# Out:
# 137622

# %%
df.drop('extent',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 30 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  GM              14 non-null      float64
#  19  BV              1005 non-null    float64
#  20  UB              965 non-null     float64
#  21  IR              1 non-null       float64
#  22  spec_B          1370 non-null    object
#  23  spec_T          965 non-null     object
#  24  G               119 non-null     float64
#  25  moid            137636 non-null  float64
#  26  class           137636 non-null  object
#  27  n               137636 non-null  float64
#  28  per             137636 non-null  float64
#  29  ma              137636 non-null  float64
# dtypes: float64(21), int64(1), object(8)
# memory usage: 32.6+ MB

# %%
df.drop('GM',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  BV              1005 non-null    float64
#  19  UB              965 non-null     float64
#  20  IR              1 non-null       float64
#  21  spec_B          1370 non-null    object
#  22  spec_T          965 non-null     object
#  23  G               119 non-null     float64
#  24  moid            137636 non-null  float64
#  25  class           137636 non-null  object
#  26  n               137636 non-null  float64
#  27  per             137636 non-null  float64
#  28  ma              137636 non-null  float64
# dtypes: float64(20), int64(1), object(8)
# memory usage: 31.5+ MB

# %%
df.drop('BV',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  UB              965 non-null     float64
#  19  IR              1 non-null       float64
#  20  spec_B          1370 non-null    object
#  21  spec_T          965 non-null     object
#  22  G               119 non-null     float64
#  23  moid            137636 non-null  float64
#  24  class           137636 non-null  object
#  25  n               137636 non-null  float64
#  26  per             137636 non-null  float64
#  27  ma              137636 non-null  float64
# dtypes: float64(19), int64(1), object(8)
# memory usage: 30.5+ MB

# %%
df.drop('UB',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  IR              1 non-null       float64
#  19  spec_B          1370 non-null    object
#  20  spec_T          965 non-null     object
#  21  G               119 non-null     float64
#  22  moid            137636 non-null  float64
#  23  class           137636 non-null  object
#  24  n               137636 non-null  float64
#  25  per             137636 non-null  float64
#  26  ma              137636 non-null  float64
# dtypes: float64(18), int64(1), object(8)
# memory usage: 29.4+ MB

# %%
df.drop('IR',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  spec_B          1370 non-null    object
#  19  spec_T          965 non-null     object
#  20  G               119 non-null     float64
#  21  moid            137636 non-null  float64
#  22  class           137636 non-null  object
#  23  n               137636 non-null  float64
#  24  per             137636 non-null  float64
#  25  ma              137636 non-null  float64
# dtypes: float64(17), int64(1), object(8)
# memory usage: 28.4+ MB

# %%
df.drop('spec_B',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 25 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  spec_T          965 non-null     object
#  19  G               119 non-null     float64
#  20  moid            137636 non-null  float64
#  21  class           137636 non-null  object
#  22  n               137636 non-null  float64
#  23  per             137636 non-null  float64
#  24  ma              137636 non-null  float64
# dtypes: float64(17), int64(1), object(7)
# memory usage: 27.3+ MB

# %%
df.drop('spec_T',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 24 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  G               119 non-null     float64
#  19  moid            137636 non-null  float64
#  20  class           137636 non-null  object
#  21  n               137636 non-null  float64
#  22  per             137636 non-null  float64
#  23  ma              137636 non-null  float64
# dtypes: float64(17), int64(1), object(6)
# memory usage: 26.3+ MB

# %%
df.drop('G',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
#  16  albedo          136406 non-null  float64
#  17  rot_per         11188 non-null   float64
#  18  moid            137636 non-null  float64
#  19  class           137636 non-null  object
#  20  n               137636 non-null  float64
#  21  per             137636 non-null  float64
#  22  ma              137636 non-null  float64
# dtypes: float64(16), int64(1), object(6)
# memory usage: 25.2+ MB

# %%
df.drop('name',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   a               137636 non-null  float64
#  1   e               137636 non-null  float64
#  2   i               137636 non-null  float64
#  3   om              137636 non-null  float64
#  4   w               137636 non-null  float64
#  5   q               137636 non-null  float64
#  6   ad              137636 non-null  float64
#  7   per_y           137636 non-null  float64
#  8   data_arc        137498 non-null  float64
#  9   condition_code  137636 non-null  object
#  10  n_obs_used      137636 non-null  int64
#  11  H               136889 non-null  float64
#  12  neo             137636 non-null  object
#  13  pha             137636 non-null  object
#  14  diameter        137636 non-null  object
#  15  albedo          136406 non-null  float64
#  16  rot_per         11188 non-null   float64
#  17  moid            137636 non-null  float64
#  18  class           137636 non-null  object
#  19  n               137636 non-null  float64
#  20  per             137636 non-null  float64
#  21  ma              137636 non-null  float64
# dtypes: float64(16), int64(1), object(5)
# memory usage: 24.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   a               137636 non-null  float64
#  1   e               137636 non-null  float64
#  2   i               137636 non-null  float64
#  3   om              137636 non-null  float64
#  4   w               137636 non-null  float64
#  5   q               137636 non-null  float64
#  6   ad              137636 non-null  float64
#  7   per_y           137636 non-null  float64
#  8   data_arc        137498 non-null  float64
#  9   condition_code  137636 non-null  object
#  10  n_obs_used      137636 non-null  int64
#  11  H               136889 non-null  float64
#  12  neo             137636 non-null  object
#  13  pha             137636 non-null  object
#  14  diameter        137636 non-null  object
#  15  albedo          136406 non-null  float64
#  16  rot_per         11188 non-null   float64
#  17  moid            137636 non-null  float64
#  18  class           137636 non-null  object
#  19  n               137636 non-null  float64
#  20  per             137636 non-null  float64
#  21  ma              137636 non-null  float64
# dtypes: float64(16), int64(1), object(5)
# memory usage: 24.2+ MB

# %%
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.head()
# Out:
#           a         e          i          om           w         q        ad  \
# 0  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684  2.979647
# 1  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865  3.411067
# 2  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332  3.354967
# 3  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909  2.570926
# 4  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324  3.066174
#
#       per_y  data_arc condition_code  ...  neo  pha diameter  albedo  \
# 0  4.608202    8822.0              0  ...    N    N    939.4  0.0900
# 1  4.616444   72318.0              0  ...    N    N      545  0.1010
# 2  4.360814   72684.0              0  ...    N    N  246.596  0.2140
# 3  3.628837   24288.0              0  ...    N    N    525.4  0.4228
# 4  4.130323   63507.0              0  ...    N    N  106.699  0.2740
#
#      rot_per     moid  class         n          per          ma
# 0   9.074170  1.59478    MBA  0.213885  1683.145708   77.372096
# 1   7.813200  1.23324    MBA  0.213503  1686.155999   59.699133
# 2   7.210000  1.03454    MBA  0.226019  1592.787285   34.925016
# 3   5.342128  1.13948    MBA  0.271609  1325.432765   95.861936
# 4  16.806000  1.09589    MBA  0.238632  1508.600458  282.366289
#
# [5 rows x 22 columns]

# %%
df['diameter']=df['diameter'].astype('float')

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.select_dtypes(['float64' , 'int64']).corr(),annot=True)
plt.show()

# %%
df.drop('rot_per',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# a                    0
# e                    0
# i                    0
# om                   0
# w                    0
# q                    0
# ad                   0
# per_y                0
# data_arc           138
# condition_code       0
# n_obs_used           0
# H                  747
# neo                  0
# pha                  0
# diameter             0
# albedo            1230
# moid                 0
# class                0
# n                    0
# per                  0
# ma                   0
# dtype: int64

# %%
df.data_arc.plot(kind='box')

# %%
df.H.plot(kind='box')

# %%
df.albedo.plot(kind='box')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   a               137636 non-null  float64
#  1   e               137636 non-null  float64
#  2   i               137636 non-null  float64
#  3   om              137636 non-null  float64
#  4   w               137636 non-null  float64
#  5   q               137636 non-null  float64
#  6   ad              137636 non-null  float64
#  7   per_y           137636 non-null  float64
#  8   data_arc        137498 non-null  float64
#  9   condition_code  137636 non-null  object
#  10  n_obs_used      137636 non-null  int64
#  11  H               136889 non-null  float64
#  12  neo             137636 non-null  object
#  13  pha             137636 non-null  object
#  14  diameter        137636 non-null  float64
#  15  albedo          136406 non-null  float64
#  16  moid            137636 non-null  float64
#  17  class           137636 non-null  object
#  18  n               137636 non-null  float64
#  19  per             137636 non-null  float64
#  20  ma              137636 non-null  float64
# dtypes: float64(16), int64(1), object(4)
# memory usage: 23.1+ MB

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x='condition_code',y='diameter')
plt.ylim((0,50))
plt.show()

# %%
df['condition_code']=df['condition_code'].astype('float')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x='class',y='diameter')
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
df['class'] = oe.fit_transform(df[['class']])
