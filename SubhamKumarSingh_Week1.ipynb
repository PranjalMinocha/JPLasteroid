# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Asteroid_Updated.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,10,15,16,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.describe(include='all')
# Out:
#          name              a              e              i             om  \
# count   21967  839712.000000  839714.000000  839714.000000  839714.000000
# unique  21967            NaN            NaN            NaN            NaN
# top     Ceres            NaN            NaN            NaN            NaN
# freq        1            NaN            NaN            NaN            NaN
# mean      NaN       2.757514       0.155636       8.949826     168.499466
# std       NaN     114.384959       0.093897       6.666087     103.096307
# min       NaN -104279.220927       0.000000       0.007546       0.000388
# 25%       NaN       2.385258       0.091454       4.069077      80.211400
# 50%       NaN       2.644219       0.143655       7.257101     160.294860
# 75%       NaN       2.996048       0.199400      12.255653     252.201519
# max       NaN    3043.149073       1.201134     175.188725     359.999800
#
#                     w              q             ad          per_y  \
# ...

# %%
df.head()
# Out:
#       name         a         e          i          om           w         q  \
# 0    Ceres  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684
# 1   Pallas  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865
# 2     Juno  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332
# 3    Vesta  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909
# 4  Astraea  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324
#
#          ad     per_y  data_arc  ...     UB  IR  spec_B spec_T     G     moid  \
# 0  2.979647  4.608202    8822.0  ...  0.426 NaN       C      G  0.12  1.59478
# 1  3.411067  4.616444   72318.0  ...  0.284 NaN       B      B  0.11  1.23324
# 2  3.354967  4.360814   72684.0  ...  0.433 NaN      Sk      S  0.32  1.03454
# 3  2.570926  3.628837   24288.0  ...  0.492 NaN       V      V  0.32  1.13948
# 4  3.066174  4.130323   63507.0  ...  0.411 NaN       S      S   NaN  1.09589
#
# ...

# %%
df.shape
# Out:
# (839714, 31)

# %%
df.count()
# Out:
# name               21967
# a                 839712
# e                 839714
# i                 839714
# om                839714
# w                 839714
# q                 839714
# ad                839708
# per_y             839713
# data_arc          824240
# condition_code    838847
# n_obs_used        839714
# H                 837025
# neo               839708
# pha               823272
# diameter          137636
# extent                18
# albedo            136409
# rot_per            18796
# GM                    14
# BV                  1021
# UB                   979
# IR                     1
# spec_B              1666
# spec_T               980
# G                    119
# moid              823272
# class             839714
# n                 839712
# per               839708
# ma                839706
# dtype: int64

# %%
df.nunique(axis=0)
# Out:
# name               21967
# a                 839702
# e                 839644
# i                 839623
# om                839712
# w                 839709
# q                 839706
# ad                839697
# per_y             839697
# data_arc           21913
# condition_code        22
# n_obs_used          3141
# H                   9831
# neo                    2
# pha                    2
# diameter           24462
# extent                18
# albedo              1057
# rot_per            11230
# GM                    14
# BV                   307
# UB                   339
# IR                     1
# spec_B                34
# spec_T               131
# G                     47
# moid              295468
# class                 14
# n                 839700
# per               839696
# ma                839699
# dtype: int64

# %%
df.dropna(subset=['diameter'], inplace=True)

# %%
df.count()
# Out:
# name               15124
# a                 137636
# e                 137636
# i                 137636
# om                137636
# w                 137636
# q                 137636
# ad                137636
# per_y             137636
# data_arc          137498
# condition_code    137636
# n_obs_used        137636
# H                 136889
# neo               137636
# pha               137636
# diameter          137636
# extent                16
# albedo            136406
# rot_per            11188
# GM                    14
# BV                  1005
# UB                   965
# IR                     1
# spec_B              1370
# spec_T               965
# G                    119
# moid              137636
# class             137636
# n                 137636
# per               137636
# ma                137636
# dtype: int64

# %%
df.nunique()
# Out:
# name               15124
# a                 137636
# e                 137636
# i                 137636
# om                137636
# w                 137636
# q                 137636
# ad                137636
# per_y             137636
# data_arc           18600
# condition_code        20
# n_obs_used          3132
# H                    763
# neo                    2
# pha                    2
# diameter           24462
# extent                16
# albedo              1057
# rot_per             8194
# GM                    14
# BV                   306
# UB                   338
# IR                     1
# spec_B                31
# spec_T               128
# G                     47
# moid               94825
# class                 11
# n                 137636
# per               137636
# ma                137636
# dtype: int64

# %%
df['condition_code'].unique()
# Out:
# array([0, 1, 3, 2, '0', '1', '2', '3', '4', '5', '9', '7', 5.0, 6.0, 4.0,
#        7.0, 9.0, 8.0, '8', '6'], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['MBA', 'OMB', 'MCA', 'AMO', 'IMB', 'TJN', 'CEN', 'APO', 'ATE',
#        'AST', 'TNO'], dtype=object)

# %%
df['neo'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['pha'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137636 entries, 0 to 810375
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            15124 non-null   object
#  1   a               137636 non-null  float64
#  2   e               137636 non-null  float64
#  3   i               137636 non-null  float64
#  4   om              137636 non-null  float64
#  5   w               137636 non-null  float64
#  6   q               137636 non-null  float64
#  7   ad              137636 non-null  float64
#  8   per_y           137636 non-null  float64
#  9   data_arc        137498 non-null  float64
#  10  condition_code  137636 non-null  object
#  11  n_obs_used      137636 non-null  int64
#  12  H               136889 non-null  float64
#  13  neo             137636 non-null  object
#  14  pha             137636 non-null  object
#  15  diameter        137636 non-null  object
# ...

# %%
df.shape
# Out:
# (137636, 31)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()*100/len(df)
# Out:
# name              89.011596
# a                  0.000000
# e                  0.000000
# i                  0.000000
# om                 0.000000
# w                  0.000000
# q                  0.000000
# ad                 0.000000
# per_y              0.000000
# data_arc           0.100264
# condition_code     0.000000
# n_obs_used         0.000000
# H                  0.542736
# neo                0.000000
# pha                0.000000
# diameter           0.000000
# extent            99.988375
# albedo             0.893662
# rot_per           91.871313
# GM                99.989828
# BV                99.269813
# UB                99.298875
# IR                99.999273
# spec_B            99.004621
# spec_T            99.298875
# G                 99.913540
# moid               0.000000
# class              0.000000
# n                  0.000000
# per                0.000000
# ma                 0.000000
# dtype: float64

# %%
df.drop(columns=['extent','GM','BV','UB','IR','G','spec_B','spec_T','name','rot_per'],inplace=True)

# %%
df.describe(include='all')
# Out:
#                     a              e              i             om  \
# count   137636.000000  137636.000000  137636.000000  137636.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         2.814613       0.145485      10.349182     169.827629
# std          1.522740       0.077573       6.835111     102.713052
# min          0.626226       0.000489       0.021855       0.000738
# 25%          2.536714       0.089623       5.120506      82.334880
# 50%          2.750859       0.138543       9.389963     160.438430
# 75%          3.092537       0.191141      13.738588     256.268387
# max        389.145964       0.984348     170.323647     359.990858
#
#                     w              q             ad          per_y  \
# count   137636.000000  137636.000000  137636.000000  137636.000000
# ...

# %%
df.isnull().sum()
# Out:
# a                    0
# e                    0
# i                    0
# om                   0
# w                    0
# q                    0
# ad                   0
# per_y                0
# data_arc           138
# condition_code       0
# n_obs_used           0
# H                  747
# neo                  0
# pha                  0
# diameter             0
# albedo            1230
# moid                 0
# class                0
# n                    0
# per                  0
# ma                   0
# dtype: int64

# %%
df.plot(subplots=True,kind='box',figsize=(28,8))
# Out:
# a                AxesSubplot(0.125,0.125;0.0407895x0.755)
# e             AxesSubplot(0.173947,0.125;0.0407895x0.755)
# i             AxesSubplot(0.222895,0.125;0.0407895x0.755)
# om            AxesSubplot(0.271842,0.125;0.0407895x0.755)
# w             AxesSubplot(0.320789,0.125;0.0407895x0.755)
# q             AxesSubplot(0.369737,0.125;0.0407895x0.755)
# ad            AxesSubplot(0.418684,0.125;0.0407895x0.755)
# per_y         AxesSubplot(0.467632,0.125;0.0407895x0.755)
# data_arc      AxesSubplot(0.516579,0.125;0.0407895x0.755)
# n_obs_used    AxesSubplot(0.565526,0.125;0.0407895x0.755)
# H             AxesSubplot(0.614474,0.125;0.0407895x0.755)
# albedo        AxesSubplot(0.663421,0.125;0.0407895x0.755)
# moid          AxesSubplot(0.712368,0.125;0.0407895x0.755)
# n             AxesSubplot(0.761316,0.125;0.0407895x0.755)
# per           AxesSubplot(0.810263,0.125;0.0407895x0.755)
# ma            AxesSubplot(0.859211,0.125;0.0407895x0.755)
# dtype: object

# %%
q1=df.a.quantile(0.25)
q3=df.a.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.a.clip(upper=uc,lower=lc,inplace=True)

q1=df.e.quantile(0.25)
q3=df.e.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.e.clip(upper=uc,lower=lc,inplace=True)

q1=df.i.quantile(0.25)
q3=df.i.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.i.clip(upper=uc,lower=lc,inplace=True)

q1=df.om.quantile(0.25)
q3=df.om.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.om.clip(upper=uc,lower=lc,inplace=True)

q1=df.w.quantile(0.25)
q3=df.w.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.w.clip(upper=uc,lower=lc,inplace=True)


q1=df.q.quantile(0.25)
q3=df.q.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.q.clip(upper=uc,lower=lc,inplace=True)

q1=df.ad.quantile(0.25)
q3=df.ad.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.ad.clip(upper=uc,lower=lc,inplace=True)

q1=df.per_y.quantile(0.25)
q3=df.per_y.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.per_y.clip(upper=uc,lower=lc,inplace=True)

q1=df.data_arc.quantile(0.25)
q3=df.data_arc.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.data_arc.clip(upper=uc,lower=lc,inplace=True)

q1=df.n_obs_used.quantile(0.25)
q3=df.n_obs_used.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.n_obs_used.clip(upper=uc,lower=lc,inplace=True)

q1=df.H.quantile(0.25)
q3=df.H.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.H.clip(upper=uc,lower=lc,inplace=True)

q1=df.albedo.quantile(0.25)
q3=df.albedo.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.albedo.clip(upper=uc,lower=lc,inplace=True)

q1=df.moid.quantile(0.25)
q3=df.moid.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.moid.clip(upper=uc,lower=lc,inplace=True)

q1=df.n.quantile(0.25)
q3=df.n.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.n.clip(upper=uc,lower=lc,inplace=True)

q1=df.ma.quantile(0.25)
q3=df.ma.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.ma.clip(upper=uc,lower=lc,inplace=True)

q1=df.per.quantile(0.25)
q3=df.per.quantile(0.75)
iqr=q3-q1
uc=q3+iqr*1.5
lc=q1-iqr*1.5
df.per.clip(upper=uc,lower=lc,inplace=True)

# %%
df.plot(subplots=True,kind='box',figsize=(28,8))
# Out:
# a                AxesSubplot(0.125,0.125;0.0407895x0.755)
# e             AxesSubplot(0.173947,0.125;0.0407895x0.755)
# i             AxesSubplot(0.222895,0.125;0.0407895x0.755)
# om            AxesSubplot(0.271842,0.125;0.0407895x0.755)
# w             AxesSubplot(0.320789,0.125;0.0407895x0.755)
# q             AxesSubplot(0.369737,0.125;0.0407895x0.755)
# ad            AxesSubplot(0.418684,0.125;0.0407895x0.755)
# per_y         AxesSubplot(0.467632,0.125;0.0407895x0.755)
# data_arc      AxesSubplot(0.516579,0.125;0.0407895x0.755)
# n_obs_used    AxesSubplot(0.565526,0.125;0.0407895x0.755)
# H             AxesSubplot(0.614474,0.125;0.0407895x0.755)
# albedo        AxesSubplot(0.663421,0.125;0.0407895x0.755)
# moid          AxesSubplot(0.712368,0.125;0.0407895x0.755)
# n             AxesSubplot(0.761316,0.125;0.0407895x0.755)
# per           AxesSubplot(0.810263,0.125;0.0407895x0.755)
# ma            AxesSubplot(0.859211,0.125;0.0407895x0.755)
# dtype: object

# %%
sns.distplot(df.albedo)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['albedo'].fillna(value=df['albedo'].mean(),inplace=True)
df.isnull().sum()
# Out:
# a                   0
# e                   0
# i                   0
# om                  0
# w                   0
# q                   0
# ad                  0
# per_y               0
# data_arc          138
# condition_code      0
# n_obs_used          0
# H                 747
# neo                 0
# pha                 0
# diameter            0
# albedo              0
# moid                0
# class               0
# n                   0
# per                 0
# ma                  0
# dtype: int64

# %%
sns.distplot(df.H)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['H'].fillna(value=df['H'].mean(),inplace=True)
df.isnull().sum()
# Out:
# a                   0
# e                   0
# i                   0
# om                  0
# w                   0
# q                   0
# ad                  0
# per_y               0
# data_arc          138
# condition_code      0
# n_obs_used          0
# H                   0
# neo                 0
# pha                 0
# diameter            0
# albedo              0
# moid                0
# class               0
# n                   0
# per                 0
# ma                  0
# dtype: int64

# %%
sns.distplot(df.H)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# a                 0
# e                 0
# i                 0
# om                0
# w                 0
# q                 0
# ad                0
# per_y             0
# data_arc          0
# condition_code    0
# n_obs_used        0
# H                 0
# neo               0
# pha               0
# diameter          0
# albedo            0
# moid              0
# class             0
# n                 0
# per               0
# ma                0
# dtype: int64

# %%
df.shape
# Out:
# (137498, 21)

# %%
df.describe(include='all')
# Out:
#                     a              e              i             om  \
# count   137498.000000  137498.000000  137498.000000  137498.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         2.785139       0.144118      10.252807     169.821737
# std          0.370028       0.071417       6.465635     102.706682
# min          1.702980       0.000489       0.021855       0.000738
# 25%          2.537203       0.089639       5.117951      82.343922
# 50%          2.751137       0.138552       9.384643     160.427779
# 75%          3.092618       0.191136      13.731117     256.215175
# max          3.926271       0.343418      26.665712     359.990858
#
#                     w              q             ad          per_y  \
# count   137498.000000  137498.000000  137498.000000  137498.000000
# ...

# %%
df.nunique()
# Out:
# a                 134115
# e                 136004
# i                 133288
# om                137498
# w                 137498
# q                 134798
# ad                133957
# per_y             134128
# data_arc           11621
# condition_code        20
# n_obs_used          2134
# H                    266
# neo                    2
# pha                    2
# diameter           24462
# albedo               629
# moid               92225
# class                 11
# n                 134210
# per               134128
# ma                137498
# dtype: int64

# %%
df.head()
# Out:
#           a         e          i          om           w         q        ad  \
# 0  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684  2.979647
# 1  2.772466  0.230337  26.665712  173.080063  310.048857  2.133865  3.411067
# 2  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332  3.354967
# 3  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909  2.570926
# 4  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324  3.066174
#
#       per_y  data_arc condition_code  ...      H  neo pha diameter  albedo  \
# 0  4.608202    8822.0              0  ...  11.85    N   N    939.4  0.0900
# 1  4.616444   14891.0              0  ...  11.85    N   N      545  0.1010
# 2  4.360814   14891.0              0  ...  11.85    N   N  246.596  0.2140
# 3  3.628837   14891.0              0  ...  11.85    N   N    525.4  0.3905
# 4  4.130323   14891.0              0  ...  11.85    N   N  106.699  0.2740
#
# ...

# %%
df.dtypes
# Out:
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used        float64
# H                 float64
# neo                object
# pha                object
# diameter           object
# albedo            float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
print(df.iloc[[15]])
# Out:
#            a         e         i          om           w         q        ad  \
# 15  2.923814  0.133568  3.096005  150.045666  228.823071  2.533285  3.314343
#
#        per_y  data_arc condition_code  ...      H  neo pha diameter  albedo  \
# 15  4.999571   12856.0              0  ...  11.85    N   N     226   0.1203
#
#       moid  class         n          per          ma
# 15  1.5358    MBA  0.197142  1826.093319  288.335893
#
# [1 rows x 21 columns]

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1be11f1e10>,
# ...
#       dtype=object)

# %%
df.groupby('class').size().plot(kind='pie',figsize=(10,10),autopct='%1.1f%%',)
plt.show()

# %%
df['class'].value_counts(normalize=True)*100
# Out:
# MBA    91.830427
# OMB     5.454625
# TJN     1.362929
# IMB     0.426915
# APO     0.352732
# MCA     0.257458
# AMO     0.195639
# ATE     0.069092
# CEN     0.035637
# TNO     0.009455
# AST     0.005091
# Name: class, dtype: float64

# %%
df.groupby('pha').size().plot(kind='pie',figsize=(10,10),autopct='%1.1f%%',)
plt.show()

# %%
df.groupby('neo').size().plot(kind='pie',figsize=(10,10),autopct='%1.1f%%',)
plt.show()

# %%
df.condition_code.nunique()
df.groupby('condition_code').size().plot(kind='pie',figsize=(10,10),autopct='%1.1f%%')
plt.show()

# %%
df['condition_code'].value_counts(normalize=True)*100
# Out:
# 0      91.778790
# 9       4.034968
# 0       1.468385
# 9.0     0.596372
# 1       0.587645
# 1       0.410915
# 2       0.219640
# 5       0.175275
# 6       0.110547
# 4       0.104002
# 3       0.098183
# 7       0.093820
# 2       0.068365
# 5.0     0.066910
# 7.0     0.056728
# 8       0.035637
# 6.0     0.026182
# 4.0     0.024000
# 3       0.023273
# 8.0     0.020364
# Name: condition_code, dtype: float64

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df.select_dtypes(['float64' , 'int64']).corr(),annot=True,annot_kws={'size': 10})

plt.show()

# %%
sns.relplot(x='a',y='per',data=df)

# %%
sns.relplot(x='moid',y='q',data=df)

# %%
sns.relplot(x='per_y',y='a',data=df)

# %%
sns.relplot(x='per_y',y='a',data=df)

# %%
sns.relplot(x='n',y='per',data=df)

# %%
sns.relplot(x='n',y='a',data=df)

# %%
sns.relplot(x='a',y='q',data=df)

# %%
sns.relplot(x='om',y='ma',data=df)

# %%
sns.distplot(df.a)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.moid)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.q)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
