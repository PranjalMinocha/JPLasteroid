# %%
#!unzip "/content/drive/MyDrive/Astro_dimeter/Asteroid_Updated.csv.zip" -d "/content/drive/MyDrive/Astro_dimeter/"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Astro_dimeter/Asteroid_Updated.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,10,15,16,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#       name         a         e          i          om           w         q  \
# 0    Ceres  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684
# 1   Pallas  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865
# 2     Juno  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332
# 3    Vesta  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909
# 4  Astraea  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324
#
#          ad     per_y  data_arc  ...     UB  IR  spec_B spec_T     G     moid  \
# 0  2.979647  4.608202    8822.0  ...  0.426 NaN       C      G  0.12  1.59478
# 1  3.411067  4.616444   72318.0  ...  0.284 NaN       B      B  0.11  1.23324
# 2  3.354967  4.360814   72684.0  ...  0.433 NaN      Sk      S  0.32  1.03454
# 3  2.570926  3.628837   24288.0  ...  0.492 NaN       V      V  0.32  1.13948
# 4  3.066174  4.130323   63507.0  ...  0.411 NaN       S      S   NaN  1.09589
#
# ...

# %%
df.describe()
# Out:
#                    a              e              i             om  \
# count  839712.000000  839714.000000  839714.000000  839714.000000
# mean        2.757514       0.155636       8.949826     168.499466
# std       114.384959       0.093897       6.666087     103.096307
# min   -104279.220927       0.000000       0.007546       0.000388
# 25%         2.385258       0.091454       4.069077      80.211400
# 50%         2.644219       0.143655       7.257101     160.294860
# 75%         2.996048       0.199400      12.255653     252.201519
# max      3043.149073       1.201134     175.188725     359.999800
#
#                    w              q             ad          per_y  \
# count  839714.000000  839714.000000  839708.000000  839713.000000
# mean      181.075796       2.404728       3.385710       6.859734
# std       104.023854       2.233172      12.748733     252.264249
# min         0.001666       0.070511       0.773684       0.000000
# ...

# %%
df.dtypes
# Out:
# name               object
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# neo                object
# pha                object
# diameter           object
# extent             object
# albedo            float64
# rot_per           float64
# GM                float64
# BV                float64
# UB                float64
# IR                float64
# spec_B             object
# spec_T             object
# G                 float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
df.isna().sum()
# Out:
# name              817747
# a                      2
# e                      0
# i                      0
# om                     0
# w                      0
# q                      0
# ad                     6
# per_y                  1
# data_arc           15474
# condition_code       867
# n_obs_used             0
# H                   2689
# neo                    6
# pha                16442
# diameter          702078
# extent            839696
# albedo            703305
# rot_per           820918
# GM                839700
# BV                838693
# UB                838735
# IR                839713
# spec_B            838048
# spec_T            838734
# G                 839595
# moid               16442
# class                  0
# n                      2
# per                    6
# ma                     8
# dtype: int64

# %%
len(df)
# Out:
# 839714

# %%
df=df.dropna(subset=["diameter"])

# %%
len(df)
# Out:
# 137636

# %%
df.dtypes
# Out:
# name               object
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# neo                object
# pha                object
# diameter           object
# extent             object
# albedo            float64
# rot_per           float64
# GM                float64
# BV                float64
# UB                float64
# IR                float64
# spec_B             object
# spec_T             object
# G                 float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
df.isna().sum()
# Out:
# name              122512
# a                      0
# e                      0
# i                      0
# om                     0
# w                      0
# q                      0
# ad                     0
# per_y                  0
# data_arc             138
# condition_code         0
# n_obs_used             0
# H                    747
# neo                    0
# pha                    0
# diameter               0
# extent            137620
# albedo              1230
# rot_per           126448
# GM                137622
# BV                136631
# UB                136671
# IR                137635
# spec_B            136266
# spec_T            136671
# G                 137517
# moid                   0
# class                  0
# n                      0
# per                    0
# ma                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y', 'data_arc',
#        'condition_code', 'n_obs_used', 'H', 'neo', 'pha', 'diameter', 'extent',
#        'albedo', 'rot_per', 'GM', 'BV', 'UB', 'IR', 'spec_B', 'spec_T', 'G',
#        'moid', 'class', 'n', 'per', 'ma'],
#       dtype='object')

# %%
df=df.drop(["name",'extent','rot_per','GM', 'BV', 'UB', 'IR', 'spec_B', 'spec_T', 'G'],axis=1)

# %%
df.head()
# Out:
#           a         e          i          om           w         q        ad  \
# 0  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684  2.979647
# 1  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865  3.411067
# 2  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332  3.354967
# 3  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909  2.570926
# 4  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324  3.066174
#
#       per_y  data_arc condition_code  ...     H  neo pha diameter  albedo  \
# 0  4.608202    8822.0              0  ...  3.34    N   N    939.4  0.0900
# 1  4.616444   72318.0              0  ...  4.13    N   N      545  0.1010
# 2  4.360814   72684.0              0  ...  5.33    N   N  246.596  0.2140
# 3  3.628837   24288.0              0  ...  3.20    N   N    525.4  0.4228
# 4  4.130323   63507.0              0  ...  6.85    N   N  106.699  0.2740
#
#       moid  class         n          per          ma
# ...

# %%
df.pha.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["pha"]=df["pha"].replace({"N":0,"Y":1})

# %%
df.isna().sum()
# Out:
# a                    0
# e                    0
# i                    0
# om                   0
# w                    0
# q                    0
# ad                   0
# per_y                0
# data_arc           138
# condition_code       0
# n_obs_used           0
# H                  747
# neo                  0
# pha                  0
# diameter             0
# albedo            1230
# moid                 0
# class                0
# n                    0
# per                  0
# ma                   0
# dtype: int64

# %%
df.nunique()
# Out:
# a                 137636
# e                 137636
# i                 137636
# om                137636
# w                 137636
# q                 137636
# ad                137636
# per_y             137636
# data_arc           18600
# condition_code        20
# n_obs_used          3132
# H                    763
# neo                    2
# pha                    2
# diameter           24462
# albedo              1057
# moid               94825
# class                 11
# n                 137636
# per               137636
# ma                137636
# dtype: int64

# %%
df.dtypes
# Out:
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# neo                object
# pha                 int64
# diameter           object
# albedo            float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
 df.neo.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["neo"]=df["neo"].replace({"N":0,"Y":1})

# %%
 df["class"].unique()
# Out:
# array(['MBA', 'OMB', 'MCA', 'AMO', 'IMB', 'TJN', 'CEN', 'APO', 'ATE',
#        'AST', 'TNO'], dtype=object)

# %%
 df["condition_code"].unique()
# Out:
# array([0, 1, 3, 2, '0', '1', '2', '3', '4', '5', '9', '7', 5.0, 6.0, 4.0,
#        7.0, 9.0, 8.0, '8', '6'], dtype=object)

# %%
 df["diameter"].unique()
# Out:
# array(['939.4', '545', '246.596', ..., 0.122, 0.651, 1.077], dtype=object)

# %%
df["diameter"]=df["diameter"].astype(float)

# %%
clas=df["class"]
condition_code=df["condition_code"]

# %%
df=df.drop(["class","condition_code"],axis=1)

# %%
df=df.astype(float)

# %%
df.dtypes
# Out:
# a             float64
# e             float64
# i             float64
# om            float64
# w             float64
# q             float64
# ad            float64
# per_y         float64
# data_arc      float64
# n_obs_used    float64
# H             float64
# neo           float64
# pha           float64
# diameter      float64
# albedo        float64
# moid          float64
# n             float64
# per           float64
# ma            float64
# dtype: object

# %%
df["class"]=clas
df["condition_code"]=condition_code

# %%
df.head()
# Out:
#           a         e          i          om           w         q        ad  \
# 0  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684  2.979647
# 1  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865  3.411067
# 2  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332  3.354967
# 3  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909  2.570926
# 4  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324  3.066174
#
#       per_y  data_arc  n_obs_used  ...  neo  pha  diameter  albedo     moid  \
# 0  4.608202    8822.0      1002.0  ...  0.0  0.0   939.400  0.0900  1.59478
# 1  4.616444   72318.0      8490.0  ...  0.0  0.0   545.000  0.1010  1.23324
# 2  4.360814   72684.0      7104.0  ...  0.0  0.0   246.596  0.2140  1.03454
# 3  3.628837   24288.0      9325.0  ...  0.0  0.0   525.400  0.4228  1.13948
# 4  4.130323   63507.0      2916.0  ...  0.0  0.0   106.699  0.2740  1.09589
#
# ...

# %% [markdown]
# ### Data is ready for EDA
# #####a- semi major axis
# #####e-eccentricity
# #####i- inclination with respect to x-y elliptical plane
# #####om - longitude of the ascending node
# #####w- argument of perihelion
# #####q - perihelion distance
# #####ad - aphelion distance
# #####per_y - orbital period
# #####data_Arc - data arc span(d)
# #####condition_Code = orbit condition code
# #####n_obs_used - number of observation used
# #####H - absolute magnitude parameter
# #####neo-Near earth object
# #####pha - Physically hazardous object
# #####diameter - diameter of asteroids
# #####extent - Object bi/tri axial ellipsoid dimensions(Km)
# #####albedo - geometric albedo
# #####rot_per - rotation period

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(15,15)

# %%
sns.heatmap(df.corr());

# %% [markdown]
# ###Here we can cleary see the relation b/w every coloumns
# ####So starting with "a:semi_major_axis"
# ###### observation

# %%
sns.scatterplot(data=df,x="a",y="diameter",hue="pha",alpha=0.5);
plt.xlim([0,20])
plt.ylim([0,300])
plt.show();

# %%
sns.scatterplot(data=df,x="e",y="diameter",hue="pha",alpha=0.5);
plt.xlim([0,1])
plt.ylim([0,300])
plt.show();

# %% [markdown]
# ####'i' : inclination with respect to x-y elliptical plane
# ####'om' : longitude of ascending node

# %%
sns.distplot(df["i"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["i","diameter"]].corr()
# Out:
#                  i  diameter
# i         1.000000  0.052609
# diameter  0.052609  1.000000

# %%
sns.distplot(df["om"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["om","diameter"]].corr()
# Out:
#                 om  diameter
# om        1.000000  0.001164
# diameter  0.001164  1.000000

# %% [markdown]
# ###Observation-'i'&'om'
# ####we can see the distrubution curve and These are not related to diameter

# %% [markdown]
# ####'w' : argument of perihelion
# #####angle made by major axis and point of minimume dist from one of foci of the orbit
# ####'q' : perihelion distance
# #####shortest distance b/w major axis and point of minimume dist from one of foci of the orbit
# ####'ad' : aphelion distance
# #####largest distance b/w major axis and point of minimume dist from one of foci of the orbit

# %%
sns.distplot(df["w"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["w","diameter"]].corr()
# Out:
#                  w  diameter
# w         1.000000  0.002966
# diameter  0.002966  1.000000

# %%
sns.distplot(df["q"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["q","diameter"]].corr()
# Out:
#                  q  diameter
# q         1.000000  0.329703
# diameter  0.329703  1.000000

# %%
sns.distplot(df["ad"])
plt.xlim([0,20])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 20.0)

# %%
df[["ad","diameter"]].corr()
# Out:
#                ad  diameter
# ad        1.00000   0.09343
# diameter  0.09343   1.00000

# %% [markdown]
# ####Observation
# #####'w' : argument of perihelion
# ######its every value is distributed almost equally and it is not related to diameter
# #####'q' : perihelion distance
# ######distribution is highly skewed means most of the value is short range and somehow it is related to diameter
# #####'ad' : aphelion distance
# ######its every value is distributed almost equally and it is not related to diameter
#
# ####overall observation is the shape of orbit similiar for 40-50% data

# %% [markdown]
# ####'per_y' : orbital period
# #####time taken for complete one revolution
# ####'data_Arc' : data arc span(d)

# %%
sns.distplot(df["per_y"])
plt.xlim([0,1000])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 1000.0)

# %%
df[["per_y","diameter"]].corr()
# Out:
#              per_y  diameter
# per_y     1.000000  0.048953
# diameter  0.048953  1.000000

# %%
sns.distplot(df["data_arc"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["data_arc","diameter"]].corr()
# Out:
#           data_arc  diameter
# data_arc  1.000000  0.491603
# diameter  0.491603  1.000000

# %%
sns.scatterplot(df["data_arc"],df["diameter"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #####somehow the data_arc value is related to diameter

# %%
df.dtypes
# Out:
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# n_obs_used        float64
# H                 float64
# neo               float64
# pha               float64
# diameter          float64
# albedo            float64
# moid              float64
# n                 float64
# per               float64
# ma                float64
# class              object
# condition_code     object
# dtype: object

# %% [markdown]
# ####'H' : absolute magnitude parameter
# ####'albedo' :geometric albedo
# ####'moid              '

# %%
sns.distplot(df["H"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["H","diameter"]].corr()
# Out:
#                  H  diameter
# H         1.000000 -0.568655
# diameter -0.568655  1.000000

# %%
sns.scatterplot(df["H"],df["diameter"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### distribution of "H" column i skewd and somehow it is negetevily related with diameter

# %%
sns.distplot(df["albedo"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["albedo","diameter"]].corr()
# Out:
#             albedo  diameter
# albedo    1.000000 -0.107397
# diameter -0.107397  1.000000

# %%
sns.scatterplot(df["albedo"],df["diameter"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #####"albedo' is related diameter to some extend

# %%
df["moid"]
# Out:
# 0         1.59478
# 1         1.23324
# 2         1.03454
# 3         1.13948
# 4         1.09589
#            ...
# 797860    1.66301
# 798077    1.36733
# 798189    1.43837
# 799752    1.16684
# 810375    1.15942
# Name: moid, Length: 137636, dtype: float64

# %%
sns.distplot(df["moid"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["moid","diameter"]].corr()
# Out:
#               moid  diameter
# moid      1.000000  0.332423
# diameter  0.332423  1.000000

# %%
sns.scatterplot(df["moid"],df["diameter"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ####moid coloumn is somehow related to diameter

# %%
df["n"]
# Out:
# 0         0.213885
# 1         0.213503
# 2         0.226019
# 3         0.271609
# 4         0.238632
#             ...
# 797860    0.174527
# 798077    0.242270
# 798189    0.176610
# 799752    0.184914
# 810375    0.262217
# Name: n, Length: 137636, dtype: float64

# %% [markdown]
# ####'n' column

# %%
sns.distplot(df["n"]);
plt.xlim([0,0.5])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
df[["n","diameter"]].corr()
# Out:
#                  n  diameter
# n         1.000000 -0.201023
# diameter -0.201023  1.000000

# %%
sns.scatterplot(df["n"],df["diameter"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ####column 'n' is related with diameter to some extend

# %%
sns.distplot(df["ma"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["ma","diameter"]].corr()
# Out:
#                 ma  diameter
# ma        1.000000  0.009659
# diameter  0.009659  1.000000

# %%
len(df["per"].unique())
# Out:
# 137636

# %%
sns.scatterplot(df["per"],df["diameter"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[["per","diameter"]].corr()
# Out:
#                per  diameter
# per       1.000000  0.048953
# diameter  0.048953  1.000000

# %% [markdown]
# ###Categorical Data
# #####Column : 'Class' and 'Condition_code'

# %% [markdown]
# #### columns that are related to diameter
# ##### q,data_arc,H,moid,n

# %%
df["condition_code"]=df["condition_code"].astype(float)

# %%
df.condition_code.value_counts()
# Out:
# 0.0    128213
# 9.0      6506
# 1.0      1373
# 2.0       396
# 5.0       333
# 7.0       207
# 6.0       188
# 4.0       176
# 3.0       167
# 8.0        77
# Name: condition_code, dtype: int64

# %%
condition_code=pd.DataFrame(df.condition_code.value_counts().index)

# %%
condition_code["values"]=df.condition_code.value_counts().values

# %%
condition_code
# Out:
#      0  values
# 0  0.0  128213
# 1  9.0    6506
# 2  1.0    1373
# 3  2.0     396
# 4  5.0     333
# 5  7.0     207
# 6  6.0     188
# 7  4.0     176
# 8  3.0     167
# 9  8.0      77

# %%
sns.barplot(condition_code[0],condition_code["values"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Above bar plot shows the suerty of the data

# %%
df['class'].value_counts()
# Out:
# MBA    126390
# OMB      7510
# TJN      1874
# IMB       588
# APO       486
# MCA       355
# AMO       269
# ATE        95
# CEN        49
# TNO        13
# AST         7
# Name: class, dtype: int64

# %%
clas=pd.DataFrame(df['class'].value_counts().index)

# %%
clas["values"]=df['class'].value_counts().values

# %%
sns.barplot(clas[0],clas["values"]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
