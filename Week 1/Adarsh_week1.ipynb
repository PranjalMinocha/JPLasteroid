# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('asteroid.csv')
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_22452\972993778.py:1: DtypeWarning: Columns (11,14,15,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('asteroid.csv')

# %%
df.head(10)
# Out:
#         full_name         a         e     G          i          om  \
# 0         1 Ceres  2.769165  0.076009  0.12  10.594067   80.305532
# 1        2 Pallas  2.772466  0.230337  0.11  34.836234  173.080063
# 2          3 Juno  2.669150  0.256942  0.32  12.988919  169.852760
# 3         4 Vesta  2.361418  0.088721  0.32   7.141771  103.810804
# 4       5 Astraea  2.574249  0.191095   NaN   5.366988  141.576604
# 5          6 Hebe  2.425160  0.203007  0.24  14.737901  138.640203
# 6          7 Iris  2.385334  0.231206   NaN   5.523651  259.563231
# 7         8 Flora  2.201764  0.156499  0.28   5.886955  110.889330
# 8         9 Metis  2.385637  0.123114  0.17   5.576816   68.908577
# 9       10 Hygiea  3.141539  0.112461   NaN   3.831560  283.202167
#
#             w         q        ad     per_y  ...    rot_per       GM     BV  \
# 0   73.597694  2.558684  2.979647  4.608202  ...   9.074170  62.6284  0.713
# ...

# %%
df.tail(10)
# Out:
#                 full_name         a         e   G          i          om  \
# 839726         (4532 P-L)  2.324578  0.200505 NaN   6.626798   17.773486
# 839727         (4717 P-L)  2.953786  0.219023 NaN   4.796715    4.018721
# 839728         (4847 P-L)  2.721596  0.238416 NaN   7.984165   14.097989
# 839729         (6013 P-L)  2.279725  0.185817 NaN   5.976037  194.238895
# 839730         (6331 P-L)  2.334803  0.282830 NaN   8.082044  355.250303
# 839731         (6344 P-L)  2.812945  0.664688 NaN   4.695700  183.310012
# 839732         (1168 T-2)  2.645238  0.259376 NaN  12.574937    1.620020
# 839733         (2060 T-2)  2.373137  0.202053 NaN   0.732484  176.499082
# 839734         (2678 T-3)  2.260404  0.258348 NaN   9.661947  204.512448
# 839735         (4571 T-3)  2.546442  0.287672 NaN   5.356238   70.709555
#
#                  w         q        ad     per_y  ...  rot_per  GM  BV  UB  \
# 839726  328.867731  1.858487  2.790669  3.544250  ...      NaN NaN NaN NaN
# ...

# %%
df.shape
# Out:
# (839736, 27)

# %%
df.dtypes
# Out:
# full_name          object
# a                 float64
# e                 float64
# G                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# diameter           object
# extent             object
# albedo            float64
# rot_per           float64
# GM                float64
# BV                float64
# UB                float64
# IR                float64
# spec_B             object
# spec_T             object
# neo                object
# pha                object
# moid              float64
# dtype: object

# %%
df.count()
# Out:
# full_name         839736
# a                 839734
# e                 839736
# G                    119
# i                 839736
# om                839736
# w                 839736
# q                 839736
# ad                839730
# per_y             839735
# data_arc          823947
# condition_code    838743
# n_obs_used        839736
# H                 837042
# diameter          137681
# extent                18
# albedo            136452
# rot_per            18796
# GM                    14
# BV                  1021
# UB                   979
# IR                     1
# spec_B              1666
# spec_T               980
# neo               839730
# pha               822814
# moid              822814
# dtype: int64

# %%
df.isnull().sum()
# Out:
# full_name              0
# a                      2
# e                      0
# G                 839617
# i                      0
# om                     0
# w                      0
# q                      0
# ad                     6
# per_y                  1
# data_arc           15789
# condition_code       993
# n_obs_used             0
# H                   2694
# diameter          702055
# extent            839718
# albedo            703284
# rot_per           820940
# GM                839722
# BV                838715
# UB                838757
# IR                839735
# spec_B            838070
# spec_T            838756
# neo                    6
# pha                16922
# moid               16922
# dtype: int64

# %% [markdown]
# We don't have enough data for 'G','diameter','extent','albedo','rot_per','GM','BV','UB','IR','spec_B','spec_T'
# So we can drop this data

# %%
df.drop('G',axis=1,inplace=True)

# %%
df.drop('diameter',axis=1,inplace=True)

# %%
df.drop('extent',axis=1,inplace=True)

# %%
df.drop('albedo',axis=1,inplace=True)

# %%
df.drop('rot_per',axis=1,inplace=True)

# %%
df.drop('GM',axis=1,inplace=True)

# %%
df.drop('BV',axis=1,inplace=True)

# %%
df.drop('UB',axis=1,inplace=True)

# %%
df.drop('IR',axis=1,inplace=True)

# %%
df.drop('spec_B',axis=1,inplace=True)

# %%
df.drop('spec_T',axis=1,inplace=True)

# %%
df.describe()
# Out:
#                    a              e              i             om  \
# count  839734.000000  839736.000000  839736.000000  839736.000000
# mean        2.843217       0.155633       8.950009     168.501641
# std        37.327031       0.093888       6.666273     103.096571
# min    -32588.942986       0.000000       0.007546       0.000388
# 25%         2.385244       0.091453       4.069043      80.212344
# 50%         2.644219       0.143654       7.257311     160.296065
# 75%         2.996035       0.199400      12.256026     252.206645
# max      3043.149073       1.201134     175.188725     359.999800
#
#                    w              q             ad          per_y  \
# count  839736.000000  839736.000000  839730.000000  839735.000000
# mean      181.076593       2.404732       3.385707       6.859544
# std       104.024110       2.233138      12.746419     252.172503
# min         0.001666       0.070511       0.773684       0.000000
# ...
